# %%
pip install finterstellar
# Out:
# Collecting finterstellar
#   Downloading https://files.pythonhosted.org/packages/78/50/ee98e50e817e58105d1d2ad137f30900e2d6feca703e7860a64998adfa21/finterstellar-0.1.6-py3-none-any.whl
# Installing collected packages: finterstellar
# Successfully installed finterstellar-0.1.6

# %% [markdown]
# ### Load Dataset

# %%
import finterstellar as fs

# %%
import os
from dotenv import load_dotenv

# hide the OTP variable from the interface
load_dotenv()
MY_ENV_VAR = os.getenv('OTP_VARIABLE')

# %%
# Coca-Cola
# get OTP key from https://finterstellar.com/
df = fs.fn_single(otp=MY_ENV_VAR, symbol='KO', window='T') # OTP: One-time-password # API Key

# %%
# display maximum columns in pandas
import pandas as pd
pd.set_option('display.max_columns', None)
df.head()
# Out:
#                      Revenue              COGS      Gross Profit  \
# 2012-09-30 47,602,000,000.00 18,828,000,000.00 28,774,000,000.00
# 2012-12-31 48,017,000,000.00 19,053,000,000.00 28,964,000,000.00
# 2013-03-31 47,915,000,000.00 19,029,000,000.00 28,886,000,000.00
# 2013-06-30 47,579,000,000.00 18,794,000,000.00 28,785,000,000.00
# 2013-09-30 47,269,000,000.00 18,734,000,000.00 28,535,000,000.00
#
#                         SG&A  Operating Income       Net Income  EPS  \
# 2012-09-30 17,714,000,000.00 10,552,000,000.00 8,810,000,000.00 1.94
# 2012-12-31 17,738,000,000.00 10,779,000,000.00 9,019,000,000.00 2.00
# 2013-03-31 17,739,000,000.00 10,678,000,000.00 8,716,000,000.00 1.94
# 2013-06-30 17,627,000,000.00 10,627,000,000.00 8,604,000,000.00 1.92
# 2013-09-30 17,421,000,000.00 10,306,000,000.00 8,740,000,000.00 1.96
#
#                       EBITDA              EBIT           Shares  \
# 2012-09-30 12,552,000,000.00 10,552,000,000.00 4,502,000,000.00
# 2012-12-31 12,761,000,000.00 10,779,000,000.00 4,504,000,000.00
# 2013-03-31 12,686,000,000.00 10,678,000,000.00 4,455,000,000.00
# 2013-06-30 12,601,000,000.00 10,627,000,000.00 4,446,000,000.00
# 2013-09-30 12,263,000,000.00 10,306,000,000.00 4,426,000,000.00
#
#             Cash & Equivalents      Receivables        Inventory  \
# 2012-09-30   18,083,000,000.00 5,083,000,000.00 3,447,000,000.00
# 2012-12-31   16,551,000,000.00 4,759,000,000.00 3,264,000,000.00
# 2013-03-31   18,428,000,000.00 5,007,000,000.00 3,607,000,000.00
# 2013-06-30   19,213,000,000.00 5,516,000,000.00 3,643,000,000.00
# 2013-09-30   20,459,000,000.00 5,116,000,000.00 3,321,000,000.00
#
#               Current Assets  Long Term Assets      Total Assets  \
# 2012-09-30 29,712,000,000.00 56,942,000,000.00 86,654,000,000.00
# 2012-12-31 30,328,000,000.00 55,846,000,000.00 86,174,000,000.00
# 2013-03-31 31,519,000,000.00 56,931,000,000.00 88,450,000,000.00
# 2013-06-30 32,572,000,000.00 56,939,000,000.00 89,511,000,000.00
# 2013-09-30 31,576,000,000.00 57,856,000,000.00 89,432,000,000.00
#
#                Current Debt  Current Liabilities    Long Term Debt  \
# 2012-09-30   341,000,000.00    27,008,000,000.00 16,181,000,000.00
# 2012-12-31 1,577,000,000.00    27,821,000,000.00 14,736,000,000.00
# 2013-03-31 4,505,000,000.00    31,102,000,000.00 14,291,000,000.00
# 2013-06-30 3,193,000,000.00    32,469,000,000.00 14,179,000,000.00
# 2013-09-30 3,194,000,000.00    33,042,000,000.00 14,173,000,000.00
#
#             Long Term Liabilities  Total Liabilities  Shareholders Equity  \
# 2012-09-30      26,056,000,000.00  53,064,000,000.00    33,590,000,000.00
# 2012-12-31      25,185,000,000.00  53,006,000,000.00    33,168,000,000.00
# 2013-03-31      24,454,000,000.00  55,556,000,000.00    32,894,000,000.00
# 2013-06-30      24,411,000,000.00  56,880,000,000.00    32,631,000,000.00
# 2013-09-30      23,925,000,000.00  56,967,000,000.00    32,465,000,000.00
#
#                Depreciation  Operating Cash Flow  Capital Expenditure  \
# 2012-09-30 2,000,000,000.00    10,514,000,000.00    -2,868,000,000.00
# 2012-12-31 1,982,000,000.00    10,645,000,000.00    -2,637,000,000.00
# 2013-03-31 2,008,000,000.00    10,630,000,000.00    -2,535,000,000.00
# 2013-06-30 1,974,000,000.00    10,423,000,000.00    -2,401,000,000.00
# 2013-09-30 1,957,000,000.00    10,517,000,000.00    -2,300,000,000.00
#
#             Investing cash flow         Dividends  Financing cash flow  Price
# 2012-09-30    -9,509,000,000.00 -4,445,000,000.00    -3,809,000,000.00  37.93
# 2012-12-31   -11,404,000,000.00 -4,595,000,000.00    -3,347,000,000.00  36.25
# 2013-03-31    -7,739,000,000.00 -4,595,000,000.00    -3,834,000,000.00  40.44
# 2013-06-30    -5,552,000,000.00 -4,689,000,000.00    -4,359,000,000.00  40.11
# 2013-09-30    -3,988,000,000.00 -4,785,000,000.00    -4,331,000,000.00  37.88

# %% [markdown]
# ### Test Joel Greenblatt's magic formula

# %%
# price factor
def factor_as_greenblatt(df):
    df["Market Cap"] = df["Price"] * df["Shares"]
    df["EV"] = df["Market Cap"] + df['Total Liabilities'] - df["Cash & Equivalents"]
    df["EV/EBIT"] = df["EV"] / df["EBIT"]
    df['ROC'] = df['EBIT'] / ( df['Total Assets'] - df['Current Liabilities'] )
    return df

# %%
df = factor_as_greenblatt(df)
print(df.columns)
fs.draw_chart(df, left='ROC', right='Market Cap')
# Out:
# Index(['Revenue', 'COGS', 'Gross Profit', 'SG&A', 'Operating Income',
#        'Net Income', 'EPS', 'EBITDA', 'EBIT', 'Shares', 'Cash & Equivalents',
#        'Receivables', 'Inventory', 'Current Assets', 'Long Term Assets',
#        'Total Assets', 'Current Debt', 'Current Liabilities', 'Long Term Debt',
#        'Long Term Liabilities', 'Total Liabilities', 'Shareholders Equity',
#        'Depreciation', 'Operating Cash Flow', 'Capital Expenditure',
#        'Investing cash flow', 'Dividends', 'Financing cash flow', 'Price',
#        'Market Cap', 'EV', 'EV/EBIT', 'ROC'],
#       dtype='object')

# %%
from IPython.display import clear_output
def magic_formula_backtest(
    price_factor, 
    quality_factor, 
    factor_function, 
    start='2011Q1', 
    end='2021Q1',
    window_size=4,
    top_k = 30
    ):
    
    terms = fs.set_terms(trade_start=start, trade_end=end)
    data = {}
    for t in terms:
        data[t] = fs.fn_consolidated(otp=MY_ENV_VAR, term=t)
    clear_output()
    print("data succesfully imported")
    s1 = {}
    s2 = {}
    s = {}
    signal = {}
    for t in terms:
        prev_t = fs.quarters_before(terms, t, window_size) # YoY Comparison
        
        data[t] = factor_function(data[t])
        
        # score of the price factor: smallest the best
        s1[t] = fs.fn_score(data[t], by=price_factor, method='relative', floor=.1, cap=2, asc=True)

        # score of the quality factor: biggest the best
        s2[t] = fs.fn_score(data[t], by=quality_factor, method='relative', floor=0, asc=False)

        # combining both price factor and quality factors picking 30 best companies from these two scores
        s[t] = fs.combine_score(s1[t], s2[t], n=top_k)
        signal[t] = list(s[t].index) # return buy vs sell signal 
    
    df = fs.backtest(signal=signal, data=data, m=3, cost=.001, rf_rate=.01)
    return df

# %%
df_magic_formula_greenblatt = magic_formula_backtest(
    price_factor='ROC', 
    quality_factor='EV/EBIT', 
    factor_function=factor_as_greenblatt
    )
fs.draw_return(df_magic_formula_greenblatt)
# Out:
# data succesfully imported
# CAGR: 16.36%
# Accumulated return: 355.59%
# Investment period: 10.0yrs
# Sharpe ratio: 1.55
# MDD: -26.16%

# %% [markdown]
# ### Test Youtube Managers's method

# %%
# price factor
def factor_as_yt_manager(df):
    # price factor
    df["Market Cap"] = df["Price"] * df["Shares"]
    df["Net Cash"] = df["Cash & Equivalents"] - df["Current Liabilities"]
    df["EV/EBITDA"] = ( df["Market Cap"] - df["Net Cash"] ) / df["EBITDA"]

    # quality factor
    df["ROE"] = df["Net Income"] / (df['Total Assets'] - df['Total Liabilities'])
    return df

# %%
df = factor_as_yt_manager(df)
fs.draw_chart(df, left='ROE', right='Market Cap')

# %%
# sky blue is NYSE and red is corresponding company

df_magic_formula_yt_manager = magic_formula_backtest(
    price_factor='ROE', 
    quality_factor='EV/EBITDA', 
    factor_function=factor_as_yt_manager
    )
fs.draw_return(df_magic_formula_yt_manager)
# Out:
# data succesfully imported
# CAGR: 11.62%
# Accumulated return: 200.59%
# Investment period: 10.0yrs
# Sharpe ratio: 1.10
# MDD: -23.86%

# %% [markdown]
# ### Test Gray & Carlisle Method

# %%
# EV/EBIT + GP/A
terms = fs.set_terms(trade_start='2011Q1', trade_end='2021Q1')
data = {}
for t in terms:
    data[t] = fs.fn_consolidated(otp=MY_ENV_VAR, term=t)
clear_output()
print("data succesfully imported")
s = {}
s1 = {}
s2 = {}
signal = {}
for t in terms:
    prev_t = fs.quarters_before(terms, t, 4)
    # price
    data[t]["Market Cap"] = data[t]["Price"] * data[t]["Shares"]
    data[t]["EV"] = data[t]["Market Cap"] + data[t]['Total Liabilities'] - data[t]["Cash & Equivalents"]
    data[t]["EV/EBIT"] = data[t]["EV"] / data[t]["EBIT"]
    
    # quality
    data[t]['Avg Assets'] = ( data[t]['Total Assets'] + data[prev_t]['Total Assets'] ) / 2
    data[t]['GP/A'] = data[t]['Gross Profit'] / data[t]['Avg Assets']
    
    # price
    s1[t] = fs.fn_score(data[t], by='EV/EBIT', method='relative', floor=.1, cap=2, asc=True)

    # quality
    s2[t] = fs.fn_score(data[t], by='GP/A', method='relative', floor=0, asc=False)

    # combine price factor and quality factor: pick best 30 companies
    s[t] = fs.combine_score(s1[t], s2[t], n=30)    
    signal[t] = list(s[t].index)

df_gray_carlisle = fs.backtest(signal=signal, data=data, m=3, cost=.001, rf_rate=.01)
fs.draw_return(df_gray_carlisle)
# Out:
# data succesfully imported
# CAGR: 18.86%
# Accumulated return: 463.57%
# Investment period: 10.0yrs
# Sharpe ratio: 1.48
# MDD: -44.97%

# %% [markdown]
# ### PER & GP/A Method

# %%
# PER + GP/A
terms = fs.set_terms(trade_start='2011Q1', trade_end='2021Q1')
data = {}
for t in terms:
    data[t] = fs.fn_consolidated(otp=MY_ENV_VAR, term=t)
clear_output()
print("data succesfully imported")

s = {}
s1 = {}
s2 = {}
signal = {}
for t in terms:
    prev_t = fs.quarters_before(terms, t, 4)
    data[t]['PER'] = data[t]['Price_M3'] / data[t]['EPS']
    data[t]['Avg Assets'] = ( data[t]['Total Assets'] + data[prev_t]['Total Assets'] ) / 2
    
    data[t]['GP/A'] = data[t]['Gross Profit'] / data[t]['Avg Assets']
    
    # price
    s1[t] = fs.fn_score(data[t], by='PER', method='relative', floor=.1, cap=2, asc=True)

    # quality
    s2[t] = fs.fn_score(data[t], by='GP/A', method='relative', floor=0, asc=False)

    # combine price factor and quality factor: pick best 30 companies
    s[t] = fs.combine_score(s1[t], s2[t], n=30)    
    signal[t] = list(s[t].index)
df_per_gpa = fs.backtest(signal=signal, data=data, m=3, cost=.001, rf_rate=.01)

# PER & GP/A
fs.draw_return(df_per_gpa) # NASDAQ companies backtest
# Out:
# data succesfully imported
# CAGR: 16.09%
# Accumulated return: 345.21%
# Investment period: 10.0yrs
# Sharpe ratio: 1.24
# MDD: -43.89%

# %%
df_per_gpa.head() # check for tickers and signals: 1 means holding, less than 1 is to reduce proportion of the portfolio, more than 1 is to increase the proportion
# Out:
#         AZPN  ABEO  OMER  EXPI  CTIC  BIG  ASRT  IIIV  SNMP  ALT  CPRX  CBRL  \
# 2011Q1  1.00  1.00  1.00  1.00  1.00 1.00  1.00  1.00  1.00 1.00  1.00  1.00
# 2011Q2  1.00  1.00  1.00  1.00  1.00 0.76  1.00  1.00  1.00 1.00  1.00  1.00
# 2011Q3  1.00  1.00  1.00  1.00  1.00 1.05  0.66  1.00  1.00 1.00  1.00  0.81
# 2011Q4  1.00  1.00  1.00  1.00  1.00 1.08  1.00  1.00  1.00 1.00  1.00  1.26
# 2012Q1  1.00  1.00  1.00  1.00  1.00 1.14  1.21  1.00  1.00 1.00  1.00  1.11
#
#         CONN  CPRI  SKY  JFIN  MVO  SFM  CVE  TUSK  YCBD  RFP  EGHT  STRA  \
# 2011Q1  1.00  1.00 1.00  1.00 1.00 1.00 1.00  1.00  1.00 1.00  1.00  1.00
# 2011Q2  1.00  1.00 1.00  1.00 1.00 1.00 1.00  1.00  1.00 1.00  1.74  0.97
# 2011Q3  1.00  1.00 1.00  1.00 1.00 1.00 1.00  1.00  1.00 0.74  0.83  0.61
# 2011Q4  1.00  1.00 1.00  1.00 1.00 1.00 1.00  1.00  1.00 1.00  0.78  1.27
# 2012Q1  1.00  1.00 1.00  1.00 1.00 1.00 1.00  1.00  1.00 1.00  1.32  1.00
#
#         PAM  AEZS  BGCP  SFIX  KFRC  NUS  MDXG  ELVT  SBOW  YELL  RNG  AIV  \
# 2011Q1 1.00  1.00  1.00  1.00  1.00 1.00  1.00  1.00  1.00  1.